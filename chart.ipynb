# %%
pip install mplfinance
# Out:
# Requirement already satisfied: mplfinance in c:\users\arthu\appdata\local\programs\python\python312\lib\site-packages (0.12.10b0)
# Requirement already satisfied: matplotlib in c:\users\arthu\appdata\local\programs\python\python312\lib\site-packages (from mplfinance) (3.8.4)
# Requirement already satisfied: pandas in c:\users\arthu\appdata\local\programs\python\python312\lib\site-packages (from mplfinance) (2.1.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\arthu\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mplfinance) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\arthu\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mplfinance) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\arthu\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mplfinance) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\arthu\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mplfinance) (1.4.5)
# Requirement already satisfied: numpy>=1.21 in c:\users\arthu\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mplfinance) (1.26.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\arthu\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mplfinance) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\arthu\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mplfinance) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\arthu\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mplfinance) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\arthu\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mplfinance) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\arthu\appdata\local\programs\python\python312\lib\site-packages (from pandas->mplfinance) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\arthu\appdata\local\programs\python\python312\lib\site-packages (from pandas->mplfinance) (2023.4)
# Requirement already satisfied: six>=1.5 in c:\users\arthu\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib->mplfinance) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\arthu\appdata\local\programs\python\python312\lib\site-packages (2.1.4)
# Requirement already satisfied: numpy<2,>=1.26.0 in c:\users\arthu\appdata\local\programs\python\python312\lib\site-packages (from pandas) (1.26.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\arthu\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\arthu\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\arthu\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2023.4)
# Requirement already satisfied: six>=1.5 in c:\users\arthu\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf
import mplfinance as mpf
# Define the stock sybol and date range
symbol = input("Enter Stock Name : ")
start_date = '2022-01-01'
end_date = '2024-04-13'

# Fetch stock data
stock_data = yf.download(symbol, start=start_date, end=end_date)

# Create the candlestick chart
mpf.plot(stock_data, type='candle', style='yahoo', title=f'{symbol} Candlestick Chart')
# Out:
# [*********************100%%**********************]  1 of 1 completed
